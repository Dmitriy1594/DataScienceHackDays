# %%
import pandas as pd

# %%
data = pd.read_csv('./docs/csv/description.csv', sep=";")
data

# %%
train = pd.read_csv('./docs/csv/train.csv', sep=";")
print(len(train))
train.head()

# %%
list(train.columns.values)

# %%
test = pd.read_csv('./docs/csv/test.csv', sep=";")
print(len(test))
test.head()

# %%
gtrain = pd.read_csv('./docs/csv/gramms_train.csv')
print(len(gtrain))
gtrain.head()

# %%
col = list(gtrain.columns.values)

# %%
gtrain.columns = ['Class'] + col[1:]

# %%
gtrain.head()

# %%
gtrain.to_csv('gramms_train_valid.csv', sep=',', encoding='utf-8')

# %%
gtest = pd.read_csv('./docs/csv/gramms_test.csv')
print(len(gtest))
gtest.head()

# %%
col = list(gtest.columns.values)

# %%
gtest.columns = ['Class'] + col[1:]

# %%
gtest.head()

# %%
gtest.to_csv('gramms_train_valid.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ## Датасет, размеченный вручную

# %%
dtrain = pd.read_csv('./datasetmaker/dataset.csv')
print(len(dtrain))
dtrain.head()

# %% [markdown]
# ## Classification and save

# %%
df = pd.read_csv('./docs/csv/train.csv', sep=";")
print(len(df))
df.head()
# Out:
# 7756
#                                            Shrt_Desc Water_(g)  Energ_Kcal  \
# 0                 BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4,7         393
# 1                              HEARTS OF PALM,CANNED      90,2          28
# 2  CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...     63,89         196
# 3            PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD     54,73         280
# 4                                  VINEGAR,DISTILLED     94,78          18
#
#   Protein_(g) Lipid_Tot_(g) Ash_(g) Carbohydrt_(g) Fiber_TD_(g) Sugar_Tot_(g)  \
# 0          12             6     3,9           73,4          5,2         13,75
# 1        2,52          0,62    2,04           4,62          2,4           NaN
# 2       24,06         11,09    1,56              0            0             0
# 3       20,43         21,35    3,51              0            0             0
# 4           0             0    0,02           0,04            0          0,04
#
# ...

# %% [markdown]
# ## Загрузка модуля с классификатором, чтобы разметить данные

# %%
from class_creator.class_creator import classPredictor

clcr = classPredictor('./class_creator/df1.txt', './class_creator/df2.txt', './class_creator/df3.txt', './class_creator/df4.txt', './class_creator/df5.txt')
# clcr.predictClass(msg)

# %%
df['Class'] = pd.Series(0, index=df.index)
df.head()
# Out:
#                                            Shrt_Desc Water_(g)  Energ_Kcal  \
# 0                 BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4,7         393
# 1                              HEARTS OF PALM,CANNED      90,2          28
# 2  CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...     63,89         196
# 3            PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD     54,73         280
# 4                                  VINEGAR,DISTILLED     94,78          18
#
#   Protein_(g) Lipid_Tot_(g) Ash_(g) Carbohydrt_(g) Fiber_TD_(g) Sugar_Tot_(g)  \
# 0          12             6     3,9           73,4          5,2         13,75
# 1        2,52          0,62    2,04           4,62          2,4           NaN
# 2       24,06         11,09    1,56              0            0             0
# 3       20,43         21,35    3,51              0            0             0
# 4           0             0    0,02           0,04            0          0,04
#
# ...

# %%
for i in range(len(df)):
#     print(df.Class[i])
    df.Class[i] = clcr.predictClass(df.Shrt_Desc[i])
#     print(df.Class[0])
# Out:
# babyfood oatmeal bananas dry
# hearts palm canned
# chicken broilers fryers thigh meat rotisserie
# pork cured arm picnic fat
# vinegar distilled
# beef nz imp tenderloin fat
# muffins blueberry prep recipe made milk
# /Users/romakindmitriy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# phyllo dough
# turkey meat smoked bone removed
# cereals quaker shredded wheat bagged
# kashi woven wheat cracker garlic
# cookies choc chip prep reg higher fat
# game meat elk
# candies mounds candy bar
# hazelnuts filberts dry wo salt
# snacks fritolay snack original flavor
# beef nz imp cube roll fat fast
# fried chick mild wing meat removed
# beef tip rst fat sel
# ...

# %%
df.Class.unique()
# Out:
# array([5, 4, 2, 1, 3])

# %%
df.to_csv('Pred_class.csv', sep=',', encoding='utf-8')

# %%
x = len(df)
y = len(df[df['Class'] == 6])
print(x, y, 'Errors: ', y*100/x)

# %%
# df[df['Class'] == 6]

# %%
df[df['Class'] != 6].to_csv('predict_cl.csv', sep=',', encoding='utf-8')

# %%
df = pd.read_csv('./docs/csv/test.csv', sep=";")
print(len(df))
df.head()
# Out:
# 862
#                                            Shrt_Desc Water_(g) Protein_(g)  \
# 0                           SILK KEY LIME SOY YOGURT     77,59        2,35
# 1               FAST FOODS,SALAD,VEG,TOSSED,WO/DRSNG     95,51        1,25
# 2                   CUTTLEFISH,MXD SP,CKD,MOIST HEAT     61,12       32,48
# 3                    GROUND TURKEY,93% LN,7% FAT,RAW     72,63       18,73
# 4  TURKEY,RTL PARTS,ENHANCED,BREAST,MEAT ONLY,CKD...     69,99       27,94
#
#   Lipid_Tot_(g) Ash_(g) Carbohydrt_(g) Fiber_TD_(g) Sugar_Tot_(g)  \
# 0          1,18    1,24          17,65          0,6         12,35
# 1          0,07    0,53           3,22          NaN           NaN
# 2           1,4    3,36           1,64            0           NaN
# 3          8,34    0,92              0            0             0
# 4          2,08     1,4              0            0             0
#
#    Calcium_(mg) Iron_(mg)  ...  Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  \
# ...

# %% [markdown]
# ## Загрузка модуля с классификатором, чтобы разметить данные

# %%
from class_creator.class_creator import classPredictor

clcr = classPredictor('./class_creator/df1.txt', './class_creator/df2.txt', './class_creator/df3.txt', './class_creator/df4.txt', './class_creator/df5.txt')
# clcr.predictClass(msg)

# %%
df['Class'] = pd.Series(0, index=df.index)
df.head()
# Out:
#                                            Shrt_Desc Water_(g) Protein_(g)  \
# 0                           SILK KEY LIME SOY YOGURT     77,59        2,35
# 1               FAST FOODS,SALAD,VEG,TOSSED,WO/DRSNG     95,51        1,25
# 2                   CUTTLEFISH,MXD SP,CKD,MOIST HEAT     61,12       32,48
# 3                    GROUND TURKEY,93% LN,7% FAT,RAW     72,63       18,73
# 4  TURKEY,RTL PARTS,ENHANCED,BREAST,MEAT ONLY,CKD...     69,99       27,94
#
#   Lipid_Tot_(g) Ash_(g) Carbohydrt_(g) Fiber_TD_(g) Sugar_Tot_(g)  \
# 0          1,18    1,24          17,65          0,6         12,35
# 1          0,07    0,53           3,22          NaN           NaN
# 2           1,4    3,36           1,64            0           NaN
# 3          8,34    0,92              0            0             0
# 4          2,08     1,4              0            0             0
#
#    Calcium_(mg) Iron_(mg)  ...  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# ...

# %%
for i in range(len(df)):
#     print(df.Class[i])
    df.Class[i] = clcr.predictClass(df.Shrt_Desc[i])
#     print(df.Class[0])
# Out:
# silk key lime soy yogurt
# fast foods salad veg tossed wo
# cuttlefish moist heat
# ground turkey fat
# turkey parts enhanced breast meat
# pork cured ham reg approx fat
# /Users/romakindmitriy/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# peanut butter smooth red fat
# pork cured ham added
# pork loin country style ribs
# ice creams strawberry
# pork comp cuts loin blade fat
# tea rtd wendy fast wo ice
# prunes low moisture
# cereals quaker nat granola oats wheat honey
# longans
# pork boston butt blade steaks fat
# beef rst fat sel
# soup mushroom cond red
# chestnuts european peeled
# beef comp cuts fat fat
# corn swt yel cut cob salt
# ...

# %%
df.to_csv('Pred_extra_1.csv', sep=',', encoding='utf-8')
