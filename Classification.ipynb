# %%
import pandas as pd

# %%
data = pd.read_csv('./docs/csv/description.csv', sep=";")
data.head()
# Out:
#     Название поля                              Описание  Unnamed: 2  \
# 0       Water_(g)                      Water (g/100 g)          NaN
# 1     Protein_(g)                    Protein (g/100 g)          NaN
# 2   Lipid_Tot_(g)            Total lipid (fat)(g/100 g)         NaN
# 3         Ash_(g)                        Ash (g/100 g)          NaN
# 4  Carbohydrt_(g)  Carbohydrate by difference (g/100 g)         NaN
#
#    Unnamed: 3  Unnamed: 4
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
train = pd.read_csv('./docs/csv/train.csv', sep=";")
print(len(train))
train.head()
# Out:
# 7756
#                                            Shrt_Desc Water_(g)  Energ_Kcal  \
# 0                 BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4,7         393
# 1                              HEARTS OF PALM,CANNED      90,2          28
# 2  CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...     63,89         196
# 3            PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD     54,73         280
# 4                                  VINEGAR,DISTILLED     94,78          18
#
#   Protein_(g) Lipid_Tot_(g) Ash_(g) Carbohydrt_(g) Fiber_TD_(g) Sugar_Tot_(g)  \
# 0          12             6     3,9           73,4          5,2         13,75
# 1        2,52          0,62    2,04           4,62          2,4           NaN
# 2       24,06         11,09    1,56              0            0             0
# 3       20,43         21,35    3,51              0            0             0
# 4           0             0    0,02           0,04            0          0,04
#
#    Calcium_(mg)  ... Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  \
# 0         651.0  ...          3       1,267        1,429        2,186
# 1          58.0  ...        NaN        0,13        0,103        0,202
# 2          13.0  ...          0       2,866        4,878        1,673
# 3          10.0  ...          0        7,67        10,14         2,32
# 4           6.0  ...          0           0            0            0
#
#    Cholestrl_(mg) GmWt_1 GmWt_Desc1 GmWt_2          GmWt_Desc2 Refuse_Pct
# 0             0.0    2.0     1 tbsp     15               .5 oz        0.0
# 1             0.0  146.0      1 cup     33             1 piece        0.0
# 2           130.0   89.0    1 thigh     85  1 serving,  (3 oz)       29.0
# 3            58.0  140.0      1 cup     85                3 oz       27.0
# 4             0.0   14.0     1 tbsp    238               1 cup        0.0
#
# [5 rows x 52 columns]

# %%
train['Shrt_Desc'][9]
# Out:
# 'CEREALS RTE,QUAKER,SHREDDED WHEAT,BAGGED CRL'

# %%
list(train.columns.values)
# Out:
# ['Shrt_Desc',
#  'Water_(g)',
#  'Energ_Kcal',
#  'Protein_(g)',
#  'Lipid_Tot_(g)',
#  'Ash_(g)',
#  'Carbohydrt_(g)',
#  'Fiber_TD_(g)',
#  'Sugar_Tot_(g)',
#  'Calcium_(mg)',
#  'Iron_(mg)',
#  'Magnesium_(mg)',
#  'Phosphorus_(mg)',
#  'Potassium_(mg)',
#  'Sodium_(mg)',
#  'Zinc_(mg)',
#  'Copper_mg)',
#  'Manganese_(mg)',
#  'Selenium_(µg)',
#  'Vit_C_(mg)',
#  'Thiamin_(mg)',
#  'Riboflavin_(mg)',
#  'Niacin_(mg)',
#  'Panto_Acid_mg)',
#  'Vit_B6_(mg)',
#  'Folate_Tot_(µg)',
#  'Folic_Acid_(µg)',
#  'Food_Folate_(µg)',
#  'Folate_DFE_(µg)',
#  'Choline_Tot_ (mg)',
#  'Vit_B12_(µg)',
#  'Vit_A_IU',
#  'Vit_A_RAE',
#  'Retinol_(µg)',
#  'Alpha_Carot_(µg)',
#  'Beta_Carot_(µg)',
#  'Beta_Crypt_(µg)',
#  'Lycopene_(µg)',
#  'Lut+Zea_ (µg)',
#  'Vit_E_(mg)',
#  'Vit_D_µg',
#  'Vit_D_IU',
#  'Vit_K_(µg)',
#  'FA_Sat_(g)',
#  'FA_Mono_(g)',
#  'FA_Poly_(g)',
#  'Cholestrl_(mg)',
#  'GmWt_1',
#  'GmWt_Desc1',
#  'GmWt_2',
#  'GmWt_Desc2',
#  'Refuse_Pct']

# %%
test = pd.read_csv('test.csv', sep=";")
print(len(test))
test.head()
# Out:
# 862
#                                            Shrt_Desc Water_(g) Protein_(g)  \
# 0                           SILK KEY LIME SOY YOGURT     77,59        2,35
# 1               FAST FOODS,SALAD,VEG,TOSSED,WO/DRSNG     95,51        1,25
# 2                   CUTTLEFISH,MXD SP,CKD,MOIST HEAT     61,12       32,48
# 3                    GROUND TURKEY,93% LN,7% FAT,RAW     72,63       18,73
# 4  TURKEY,RTL PARTS,ENHANCED,BREAST,MEAT ONLY,CKD...     69,99       27,94
#
#   Lipid_Tot_(g) Ash_(g) Carbohydrt_(g) Fiber_TD_(g) Sugar_Tot_(g)  \
# 0          1,18    1,24          17,65          0,6         12,35
# 1          0,07    0,53           3,22          NaN           NaN
# 2           1,4    3,36           1,64            0           NaN
# 3          8,34    0,92              0            0             0
# 4          2,08     1,4              0            0             0
#
#    Calcium_(mg) Iron_(mg)  ...  Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  \
# 0         176.0      0,64  ...         NaN           0          NaN
# 1          13.0      0,63  ...         NaN        0,01        0,004
# 2         180.0     10,84  ...         NaN       0,236        0,162
# 3          21.0      1,17  ...           0        2,17        2,843
# 4          15.0      0,59  ...           0       0,428         0,67
#
#    FA_Poly_(g) Cholestrl_(mg) GmWt_1   GmWt_Desc1 GmWt_2 GmWt_Desc2 Refuse_Pct
# 0          NaN            0.0  170.0  1 container    NaN        NaN        0.0
# 1        0,034            0.0  104.0      .75 cup    207    1.5 cup        0.0
# 2        0,268          224.0   85.0         3 oz    NaN        NaN        0.0
# 3        2,537           74.0   28.0         1 oz    453       1 lb        0.0
# 4        0,668           74.0   85.0         3 oz    852   1 breast       24.0
#
# [5 rows x 51 columns]

# %%
gtrain = pd.read_csv('gramms_train.csv')
print(len(gtrain))
gtrain.head()
# Out:
# 7756
#    Unnamed: 0                                          Shrt_Desc  Water_(g)  \
# 0           0                 BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1           1                              HEARTS OF PALM,CANNED      90.20
# 2           2  CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3           3            PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4           4                                  VINEGAR,DISTILLED      94.78
#
#    Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 0        12.00           6.00     3.90           73.40           5.2
# 1         2.52           0.62     2.04            4.62           2.4
# 2        24.06          11.09     1.56            0.00           0.0
# 3        20.43          21.35     3.51            0.00           0.0
# 4         0.00           0.00     0.02            0.04           0.0
#
#    Sugar_Tot_(g)  Copper_mg)  ...  Lut+Zea_ (g)  Vit_E_(g)  Vit_K_(g)  \
# 0          13.75       0.391  ...       0.00157    0.00500    0.00003
# 1            NaN       0.133  ...           NaN        NaN        NaN
# 2           0.00       0.084  ...       0.00000    0.00025    0.00000
# 3           0.00       0.113  ...       0.00000    0.00024    0.00000
# 4           0.04       0.006  ...       0.00000    0.00000    0.00000
#
#    Cholestrl_(g)  GmWt_1  GmWt_Desc1  GmWt_2          GmWt_Desc2  Refuse_Pct  \
# 0          0.000     2.0      1 tbsp    15.0               .5 oz         0.0
# 1          0.000   146.0       1 cup    33.0             1 piece         0.0
# 2          0.130    89.0     1 thigh    85.0  1 serving,  (3 oz)        29.0
# 3          0.058   140.0       1 cup    85.0                3 oz        27.0
# 4          0.000    14.0      1 tbsp   238.0               1 cup         0.0
#
#    Energ_Kcal
# 0         393
# 1          28
# 2         196
# 3         280
# 4          18
#
# [5 rows x 53 columns]

# %%
col = list(gtrain.columns.values)

# %%
gtrain.columns = ['Class'] + col[1:]

# %%
gtrain.head()
# Out:
#    Class                                          Shrt_Desc  Water_(g)  \
# 0      0                 BABYFOOD,CRL,OATMEAL,W/BANANAS,DRY       4.70
# 1      1                              HEARTS OF PALM,CANNED      90.20
# 2      2  CHICKEN,BROILERS OR FRYERS,THIGH,MEAT ONLY,CKD...      63.89
# 3      3            PORK,CURED,SHLDR,ARM PICNIC,LN&FAT,RSTD      54.73
# 4      4                                  VINEGAR,DISTILLED      94.78
#
#    Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 0        12.00           6.00     3.90           73.40           5.2
# 1         2.52           0.62     2.04            4.62           2.4
# 2        24.06          11.09     1.56            0.00           0.0
# 3        20.43          21.35     3.51            0.00           0.0
# 4         0.00           0.00     0.02            0.04           0.0
#
#    Sugar_Tot_(g)  Copper_mg)  ...  Lut+Zea_ (g)  Vit_E_(g)  Vit_K_(g)  \
# 0          13.75       0.391  ...       0.00157    0.00500    0.00003
# 1            NaN       0.133  ...           NaN        NaN        NaN
# 2           0.00       0.084  ...       0.00000    0.00025    0.00000
# 3           0.00       0.113  ...       0.00000    0.00024    0.00000
# 4           0.04       0.006  ...       0.00000    0.00000    0.00000
#
#    Cholestrl_(g)  GmWt_1  GmWt_Desc1  GmWt_2          GmWt_Desc2  Refuse_Pct  \
# 0          0.000     2.0      1 tbsp    15.0               .5 oz         0.0
# 1          0.000   146.0       1 cup    33.0             1 piece         0.0
# 2          0.130    89.0     1 thigh    85.0  1 serving,  (3 oz)        29.0
# 3          0.058   140.0       1 cup    85.0                3 oz        27.0
# 4          0.000    14.0      1 tbsp   238.0               1 cup         0.0
#
#    Energ_Kcal
# 0         393
# 1          28
# 2         196
# 3         280
# 4          18
#
# [5 rows x 53 columns]

# %%
gtrain.to_csv('gramms_train_valid.csv', sep=',', encoding='utf-8')

# %%
gtest = pd.read_csv('gramms_test.csv')
print(len(gtest))
gtest.head()

# %%
col = list(gtest.columns.values)

# %%
gtest.columns = ['Class'] + col[1:]

# %%
gtest.head()

# %%
gtest.to_csv('gramms_train_valid.csv', sep=',', encoding='utf-8')

# %%
dtrain = pd.read_csv('./datasetmaker/dataset.csv')
print(len(dtrain))
dtrain.head()
# Out:
# 259
#    Unnamed: 0  Class                                          Shrt_Desc  \
# 0         NaN      3                           SILK KEY LIME SOY YOGURT
# 1         NaN      5               FAST FOODS,SALAD,VEG,TOSSED,WO/DRSNG
# 2         NaN      4                   CUTTLEFISH,MXD SP,CKD,MOIST HEAT
# 3         NaN      4                    GROUND TURKEY,93% LN,7% FAT,RAW
# 4         NaN      4  TURKEY,RTL PARTS,ENHANCED,BREAST,MEAT ONLY,CKD...
#
#    Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0      77.59         2.35           1.18     1.24           17.65
# 1      95.51         1.25           0.07     0.53            3.22
# 2      61.12        32.48           1.40     3.36            1.64
# 3      72.63        18.73           8.34     0.92            0.00
# 4      69.99        27.94           2.08     1.40            0.00
#
#    Fiber_TD_(g)  Sugar_Tot_(g)  ...  Vit_B12_(g)  Retinol_(g)  \
# 0           0.6          12.35  ...          NaN          NaN
# 1           NaN            NaN  ...     0.000000      0.00000
# 2           0.0            NaN  ...     0.000054      0.00203
# 3           0.0           0.00  ...     0.000012      0.00022
# 4           0.0           0.00  ...     0.000003      0.00003
#
#    Alpha_Carot_(g)  Beta_Carot_(g)  Beta_Crypt_(g)  Lycopene_(g)  \
# 0              NaN             NaN             NaN           NaN
# 1              NaN             NaN             NaN           NaN
# 2              NaN             NaN             NaN           NaN
# 3              0.0             0.0             0.0           0.0
# 4              0.0             0.0             0.0           0.0
#
#    Lut+Zea_ (g)  Vit_E_(g)  Vit_K_(g)  Cholestrl_(g)
# 0           NaN        NaN        NaN          0.000
# 1           NaN        NaN        NaN          0.000
# 2           NaN        NaN        NaN          0.224
# 3       0.00000    0.00011        0.0          0.074
# 4       0.00005    0.00008        0.0          0.074
#
# [5 rows x 53 columns]

# %%
import re

# %%
txt = "Sukanya, Rajib and Naba are my good friends. " + \
    "Sukanya is getting married next year. " + \
    "Marriage is a big step in one’s life." + \
    "It is both exciting and frightening. " + \
    "But friendship is a sacred bond between people." + \
    "It is a special kind of love between us. " + \
    "Many of you must have tried searching for a friend " + \
    "but never found the right one."

# %%
re.findall(r"chick",txt)
# Out:
# []
